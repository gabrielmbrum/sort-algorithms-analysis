# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Dados fornecidos
n = [10, 100, 1000, 10000, 100000, 1000000]  # Tamanhos do array
sorted_times = [0.000001, 0.000001, 0.000012, 0.000028, 0.000085, 0.000779]
unsorted_times = [0.0000001, 0.000012, 0.001128, 0.117072, 10.622649, 1091.755737]
randomized_times = [0.0000001, 0.000034, 0.001607, 0.041509, 5.900282, 623.060959]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bubble Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bubble Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bubble Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Insertion
sorted_times = [0.000001, 0.000001, 0.000002, 0.000019, 0.000174, 0.001853]
unsorted_times = [0.000001, 0.000021, 0.000964, 0.081483, 8.569336, 907.423855]
randomized_times = [0.000001, 0.000012, 0.000552, 0.044058, 4.314448, 440.021067]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Insertion Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Insertion Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Insertion Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Selection Sort
sorted_times = [0.000004, 0.000037, 0.002236, 0.38866, 3.490388, 353.801694]
unsorted_times = [0.000003, 0.000061, 0.002165, 0.038482, 3.491498, 354.710303]
randomized_times = [0.000003, 0.000071, 0.001727, 0.039493, 3.604798, 350.356539]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Selection Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Selection Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Selection Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Quick Sort
sorted_times = [0.000001, 0.000002, 0.000021, 0.000195, 0.002021, 0.020862]
unsorted_times = [0.000001, 0.000002, 0.000021, 0.000177, 0.002078, 0.020492]
randomized_times = [0.000001, 0.000005, 0.000054, 0.000410, 0.005061, 0.056918]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Quick Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1

# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Quick Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Quick Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Heap Sort
sorted_times = [0.000001, 0.000010, 0.000129, 0.001467, 0.017628, 0.208090]
unsorted_times = [0.000001, 0.000008, 0.000125, 0.001439, 0.017442, 0.209321]
randomized_times = [0.000001, 0.000008, 0.000123, 0.001574, 0.019132, 0.246424]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Heap Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Heap Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Heap Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Counting Sort
sorted_times = [0.000001, 0.000001, 0.000012, 0.000104, 0.000725, 0.008453]
unsorted_times = [0.0000001, 0.000001, 0.000010, 0.000103, 0.000735, 0.007741]
randomized_times = [0.0000001, 0.000001, 0.000011, 0.000123, 0.000880, 0.017655]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Counting Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')


# Adicionando título e rótulos aos eixos
plt.title('Counting Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))

#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Counting Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Merge Sort
sorted_times = [0.000001, 0.000005, 0.000051, 0.000567, 0.006552, 0.070394]
unsorted_times = [0.000001, 0.000004, 0.000046, 0.000533, 0.006978, 0.064166]
randomized_times = [0.0000001, 0.000005, 0.000057, 0.000939, 0.008481, 0.092154]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Merge Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Merge Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Merge Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Shell Sort
sorted_times = [0.0000001, 0.000001, 0.000014, 0.000199, 0.001526, 0.019737]
unsorted_times = [0.0000001, 0.000001, 0.000018, 0.000243, 0.001909, 0.021365]
randomized_times = [0.0000001, 0.000003, 0.000043, 0.000526, 0.006952, 0.085269]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Shell Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Shell Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Shell Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Radix Sort
sorted_times = [0.000001, 0.000002, 0.000024, 0.000313, 0.004427, 0.042823]
unsorted_times = [0.0000001, 0.000003, 0.000030, 0.000379, 0.004466, 0.047688]
randomized_times = [0.0000001, 0.000002, 0.000025, 0.000320, 0.003918, 0.042837]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Radix Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Radix Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Radix Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Bucket Sort
sorted_times = [0.000004, 0.000006, 0.000020, 0.000122, 0.001637, 0.018961]
unsorted_times = [0.0000003, 0.000005, 0.000020, 0.000134, 0.001905, 0.021970]
randomized_times = [0.000003, 0.000006, 0.000039, 0.000318, 0.004141, 0.055540]

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in sorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bucket Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
#plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in unsorted_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bucket Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando os tempos de execução
plt.figure(figsize=(10, 6))


#plt.plot(n, sorted_times, label='Sorted', marker='o', color='green')
#plt.plot(n, unsorted_times, label='Unsorted', marker='o', color='red')
plt.plot(n, randomized_times, label='Randomized', marker='o', color='blue')
i=0
for txt in randomized_times:
    plt.text(n[i], txt, f'{txt:.6f}', fontsize=9, ha='right', va='bottom', color='black')
    i+=1
# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Bucket Sort - Tempo de Execução por Tamanho do Array')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
#Bucket Sort
sorted_times_bucket = [0.000004, 0.000006, 0.000020, 0.000122, 0.001637, 0.018961]
unsorted_times_bucket = [0.0000003, 0.000005, 0.000020, 0.000134, 0.001905, 0.021970]
randomized_times_bucket = [0.000003, 0.000006, 0.000039, 0.000318, 0.004141, 0.055540]

#Radix Sort
sorted_times_radix = [0.000001, 0.000002, 0.000024, 0.000313, 0.004427, 0.042823]
unsorted_times_radix = [0.0000001, 0.000003, 0.000030, 0.000379, 0.004466, 0.047688]
randomized_times_radix = [0.0000001, 0.000002, 0.000025, 0.000320, 0.003918, 0.042837]
#Shell Sort
sorted_times_shell = [0.0000001, 0.000001, 0.000014, 0.000199, 0.001526, 0.019737]
unsorted_times_shell = [0.0000001, 0.000001, 0.000018, 0.000243, 0.001909, 0.021365]
randomized_times_shell = [0.0000001, 0.000003, 0.000043, 0.000526, 0.006952, 0.085269]

#Merge Sort
sorted_times_merge = [0.000001, 0.000005, 0.000051, 0.000567, 0.006552, 0.070394]
unsorted_times_merge = [0.000001, 0.000004, 0.000046, 0.000533, 0.006978, 0.064166]
randomized_times_merge = [0.0000001, 0.000005, 0.000057, 0.000939, 0.008481, 0.092154]

#Counting Sort
sorted_times_counting = [0.000001, 0.000001, 0.000012, 0.000104, 0.000725, 0.008453]
unsorted_times_counting = [0.0000001, 0.000001, 0.000010, 0.000103, 0.000735, 0.007741]
randomized_times_counting = [0.0000001, 0.000001, 0.000011, 0.000123, 0.000880, 0.017655]

#Heap Sort
sorted_times_heap = [0.000001, 0.000010, 0.000129, 0.001467, 0.017628, 0.208090]
unsorted_times_heap = [0.000001, 0.000008, 0.000125, 0.001439, 0.017442, 0.209321]
randomized_times_heap = [0.000001, 0.000008, 0.000123, 0.001574, 0.019132, 0.246424]

#Quick Sort
sorted_times_quick = [0.000001, 0.000002, 0.000021, 0.000195, 0.002021, 0.020862]
unsorted_times_quick = [0.000001, 0.000002, 0.000021, 0.000177, 0.002078, 0.020492]
randomized_times_quick = [0.000001, 0.000005, 0.000054, 0.000410, 0.005061, 0.056918]

#Insertion
sorted_times_insertion = [0.000001, 0.000001, 0.000002, 0.000019, 0.000174, 0.001853]
unsorted_times_insertion = [0.000001, 0.000021, 0.000964, 0.081483, 8.569336, 907.423855]
randomized_times_insertion = [0.000001, 0.000012, 0.000552, 0.044058, 4.314448, 440.021067]

#Bubble Sort
sorted_times_bubble = [0.000001, 0.000001, 0.000012, 0.000028, 0.000085, 0.000779]
unsorted_times_bubble = [0.0000001, 0.000012, 0.001128, 0.117072, 10.622649, 1091.755737]
randomized_times_bubble = [0.0000001, 0.000034, 0.001607, 0.041509, 5.900282, 623.060959]

#Selection Sort
sorted_times_selection = [0.000004, 0.000037, 0.002236, 0.38866, 3.490388, 353.801694]
unsorted_times_selection = [0.000003, 0.000061, 0.002165, 0.038482, 3.491498, 354.710303]
randomized_times_selection = [0.000003, 0.000071, 0.001727, 0.039493, 3.604798, 350.356539]

# %%
# Plotando o grafico de todos os sort - sorted
plt.figure(figsize=(10, 6))


plt.plot(n, sorted_times_bubble, label='Bubble Sort', marker='o', color='blue')
plt.plot(n, sorted_times_insertion, label='Insertion Sort', marker='o', color='green')
plt.plot(n, sorted_times_quick, label='Quick Sort', marker='o', color='red')
plt.plot(n, sorted_times_heap, label='Heap Sort', marker='o', color='yellow')
plt.plot(n, sorted_times_counting, label='Counting Sort', marker='o', color='black')
plt.plot(n, sorted_times_merge, label='Merge Sort', marker='o', color='purple')
plt.plot(n, sorted_times_shell, label='Shell Sort', marker='o', color='brown')
plt.plot(n, sorted_times_radix, label='Radix Sort', marker='o', color='grey')
plt.plot(n, sorted_times_bucket, label='Bucket Sort', marker='o', color='orange')
plt.plot(n, sorted_times_selection, label='Selection Sort', marker='o', color='pink')


# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Sorted - Tempo de Execução por tipos de algoritimo')

plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando o grafico de todos os sort - sorted
plt.figure(figsize=(10, 6))


plt.plot(n, unsorted_times_bubble, label='Bubble Sort', marker='o', color='blue')
plt.plot(n, unsorted_times_insertion, label='Insertion Sort', marker='o', color='green')
plt.plot(n, unsorted_times_quick, label='Quick Sort', marker='o', color='red')
plt.plot(n, unsorted_times_heap, label='Heap Sort', marker='o', color='yellow')
plt.plot(n, unsorted_times_counting, label='Counting Sort', marker='o', color='black')
plt.plot(n, unsorted_times_merge, label='Merge Sort', marker='o', color='purple')
plt.plot(n, unsorted_times_shell, label='Shell Sort', marker='o', color='brown')
plt.plot(n, unsorted_times_radix, label='Radix Sort', marker='o', color='grey')
plt.plot(n, unsorted_times_bucket, label='Bucket Sort', marker='o', color='orange')
plt.plot(n, unsorted_times_selection, label='Selection Sort', marker='o', color='pink')


# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Unsorted - Tempo de Execução por tipos de algoritimo')

plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %%
# Plotando o grafico de todos os sort - randomizado
plt.figure(figsize=(10, 6))


plt.plot(n, randomized_times_bubble, label='Bubble Sort', marker='o', color='blue')
plt.plot(n, randomized_times_insertion, label='Insertion Sort', marker='o', color='green')
plt.plot(n, randomized_times_quick, label='Quick Sort', marker='o', color='red')
plt.plot(n, randomized_times_heap, label='Heap Sort', marker='o', color='yellow')
plt.plot(n, randomized_times_counting, label='Counting Sort', marker='o', color='black')
plt.plot(n, randomized_times_merge, label='Merge Sort', marker='o', color='purple')
plt.plot(n, randomized_times_shell, label='Shell Sort', marker='o', color='brown')
plt.plot(n, randomized_times_radix, label='Radix Sort', marker='o', color='grey')
plt.plot(n, randomized_times_bucket, label='Bucket Sort', marker='o', color='orange')
plt.plot(n, randomized_times_selection, label='Selection Sort', marker='o', color='pink')


# Ajustando os eixos logarítmicos para melhor visualização
plt.xscale('log')
plt.yscale('log')

# Adicionando título e rótulos aos eixos
plt.title('Randomizado - Tempo de Execução por tipos de algoritimo')
plt.xlabel('Tamanho do Array (n)')
plt.ylabel('Tempo de Execução (segundos)')

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()
